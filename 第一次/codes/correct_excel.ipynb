# %%
import pandas as pd

# %%
data = pd.read_csv("./new 1.txt", sep="\t")

# %%
data
# Out:
#                        t      y1          y2
# 0    2018-09-21 15:00:00     803  -1390.0810
# 1    2018-09-21 16:00:00   40422  18643.7580
# 2    2018-09-21 17:00:00   60509  20703.4180
# 3    2018-09-21 18:00:00   88825  16628.6290
# 4    2018-09-21 19:00:00  131011  16794.7680
# 5    2018-09-21 20:00:00  139467  25122.7270
# 6    2018-09-21 21:00:00  179168  24820.2930
# 7    2018-09-21 22:00:00  163183  25383.5120
# 8    2018-09-21 23:00:00  123305  19550.9240
# 9    2018-09-22 00:00:00   87926  24573.9570
# 10   2018-09-22 01:00:00   45563  23891.4800
# 11   2018-09-22 02:00:00   29746  23016.9510
# 12   2018-09-22 03:00:00   22503  23583.5160
# 13   2018-09-22 04:00:00   15092  18809.5860
# 14   2018-09-22 05:00:00   15406  24855.3610
# 15   2018-09-22 06:00:00   25802  23912.0490
# 16   2018-09-22 07:00:00   34789  24336.2640
# 17   2018-09-22 08:00:00   50842  24234.6450
# 18   2018-09-22 09:00:00   51373  22832.2900
# 19   2018-09-22 10:00:00   56137  22720.7680
# ...

# %%
def get_date(x):
    return x.split()[0]

# %%
data["date"] = data["t"].apply(get_date)

# %%
# data.groupby(df['data1'].groupby(df['key1']))
data.groupby(data['date']).sum()['y2'].values.tolist()
# Out:
# [166257.94799999997,
#  463280.2279999999,
#  294725.7707,
#  246125.2498,
#  -105482.86973,
#  -66781.08343,
#  -286164.5158,
#  -144204.18012999996,
#  78489.01159999998,
#  47804.93940000002,
#  164781.16330000001,
#  162157.02659999998,
#  161550.5318,
#  174523.16430000003,
#  191339.62900000002,
#  208134.615,
#  77334.64230000002,
#  72732.3779,
#  100648.79459999998,
#  82130.73300000002,
#  82233.0928]

# %%
# data["y1"]
